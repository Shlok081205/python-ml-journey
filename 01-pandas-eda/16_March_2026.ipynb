# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/shlok/College/SemIV/FCSP2/01-pandas-eda/sample_data/ipl-matches.csv")

# %%
df[(df['WinningTeam']=="Gujarat Titans") & (df['SuperOver']=="Y")].shape[0]
# Out:
# 0

# %%
df[(df["WinningTeam"]=="Royal Challengers Bangalore")&((df["Team2"]=="Kolkata Knight Riders")|(df["Team1"]=="Kolkata Knight Riders"))].shape[0]
# Out:
# 14

# %%
df[df["TossWinner"] ==df["WinningTeam"]].shape[0]
# Out:
# 489

# %%
df[(df["WonBy"]=="Wickets")&(df["method"]=="D/L")].shape[0]
# Out:
# 8

# %%
df[(df["TossWinner"]=="Rajasthan Royals")&(df["WinningTeam"]=="Rajasthan Royals")].shape[0]
# Out:
# 49

# %%
df[(df["Player_of_Match"]=="V Kohli")&((df["Team2"]=="Chennai Super Kings")|(df["Team1"]=="Chennai Super Kings"))].shape[0]
# Out:
# 2

# %%
df[(df['City']=="Dubai")&(df["MatchNumber"]=="Final")]["TossWinner"]
# Out:
# 74    Kolkata Knight Riders
# Name: TossWinner, dtype: object

# %%
df[(df["MatchNumber"]=="Final")&(df["TossWinner"]=="Kolkata Knight Riders")&(df["TossDecision"]=="field")]
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 74   1254117      Dubai  2021-10-15   2021       Final    Chennai Super Kings
# 492   734049  Bangalore  2014-06-01   2014       Final  Kolkata Knight Riders
#
#                      Team2                                Venue  \
# 74   Kolkata Knight Riders  Dubai International Cricket Stadium
# 492        Kings XI Punjab                M Chinnaswamy Stadium
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# 74   Kolkata Knight Riders        field         N    Chennai Super Kings
# 492  Kolkata Knight Riders        field         N  Kolkata Knight Riders
#
#        WonBy  Margin method Player_of_Match  \
# 74      Runs    27.0    NaN    F du Plessis
# 492  Wickets     3.0    NaN       MK Pandey
#
#                                           Team1Players  \
# 74   ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 492  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
#
# ...

# %%
import matplotlib.pyplot as plt

pd.plotting.scatter_matrix(df)
plt.show()

# %%
import seaborn as sns 

sns.boxplot(df)
# Out:
# <Axes: >
